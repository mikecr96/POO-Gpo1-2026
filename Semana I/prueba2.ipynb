# %% [markdown]
# # Conversión de tipos de datos en Python
#
# ## Conversiones HACIA entero (int)

# %%
PI = 3.14151926
print(PI)
# PI = True
# print(PI)
# a = 1
PI_to_int = int(PI)
print(PI_to_int)
# Out:
# 3.14151926
# 3

# %%
int(7.999999999)
# Out:
# 7

# %%
type(int("1234"))
# Out:
# int

# %%
# int("3.14151926")

# %%
# int("Hola mundo")

# %% [markdown]
# ## conversión hacia float

# %%
float(123)
# Out:
# 123.0

# %%
float("3.14151926")
# Out:
# 3.14151926

# %%
# float([])

# %%
float(True)
# Out:
# 1.0

# %%
float(False)
# Out:
# 0.0

# %% [markdown]
# ## conversión hacia str

# %%
str(12345)
# Out:
# '12345'

# %%
str(3.1416)
# Out:
# '3.1416'

# %%
str(True)
# Out:
# 'True'

# %%
str([1, 2, 3])
# Out:
# '[1, 2, 3]'

# %% [markdown]
# ## conversión hacia list

# %%
list("hola mundo")
# Out:
# ['h', 'o', 'l', 'a', ' ', 'm', 'u', 'n', 'd', 'o']

# %%
list(123)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 list(123)
#
# TypeError: 'int' object is not iterable

# %%
# list(True, True, True)

# %%
list((1, 2, 3))
# Out:
# [1, 2, 3]

# %%
list({1, 1, 1, 1, 1, 1, 1, 1, 1, 2, 3, 4, 5})
# Out:
# [1, 2, 3, 4, 5]

# %%
list({"gato": "mamífero", "perro": "mamífero"})
# Out:
# ['gato', 'perro']

# %% [markdown]
# ## Conversiones hacia bool

# %%
bool(0)
# Out:
# False

# %%
bool(0.5)
# Out:
# True

# %%
bool("True")
# Out:
# True

# %%
bool("hola")
# Out:
# True

# %%
bool("mundo")
# Out:
# True

# %%
bool("")
# Out:
# False

# %% [markdown]
# ---
#
# ## STRINGS

# %%
cadena = "hola mundo"
print(cadena)
# Indexing - tiene que ser numérico
cadena[4] # Python es zero-indexed
# Out:
# hola mundo
# ' '

# %%
cadena[-2]
# Out:
# 'd'

# %%
# cadena[3] = "e"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 cadena[3] = "e"
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# ## Métodos especiales de los str

# %%
dir(cadena)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %%
string = "hola mundo mundial, saludos desde el aula A del CDC"

# Notación punto (.)
print(string.lower())
print(string)
# Out:
# hola mundo mundial, saludos desde el aula a del cdc
# hola mundo mundial, saludos desde el aula A del CDC

# %%
string.split(",")
# Out:
# ['hola mundo mundial', ' saludos desde el aula A del CDC']

# %%
string.upper()
# Out:
# 'HOLA MUNDO MUNDIAL, SALUDOS DESDE EL AULA A DEL CDC'

# %%
string.capitalize()
# Out:
# 'Hola mundo mundial, saludos desde el aula a del cdc'

# %%
string
# Out:
# 'hola mundo mundial, saludos desde el aula A del CDC'

# %%
string.islower()
# Out:
# False

# %%
string.isupper()
# Out:
# False

# %%
string.isdigit()
# Out:
# False

# %%
"holamundo".isalpha()
# Out:
# True

# %%
"hola".isidentifier()
# Out:
# True

# %%
"MENÚ PRINCIPAL".center(50, "*")
# Out:
# '******************MENÚ PRINCIPAL******************'

# %%
"A" + "A" # Concatenación
# Out:
# 'AA'
