# %%
print("Hola mundo")
# Out:
# Hola mundo

# %%
numero1 = 100

# %%
print(numero1)
# Out:
# 100

# %%
miNombre = "Miguel"

# %%
print(miNombre)
# Out:
# Miguel

# %%
var1 = "Miguel"
var2 = 123
var3 = True

print(var1)
print(var2)
print(var3)
# Out:
# Miguel
# 123
# True

# %%
# En esta celda voy a generar una variable de tipo entero
# Comentario single-line

# %%
"""
Primera línea
Segunda línea
Tercera línea
"""
# Out:
# '\nPrimera línea\nSegunda línea\nTercera línea\n'

# %%
type(123)
# Out:
# int

# %%
"""
int
float
str
bool
list
tuple
set
dict
"""
# Out:
# '\nint\nfloat\nstr\nbool\nlist\ntuple\nset\ndict\n'

# %%
type(3.14151926)
# Out:
# float

# %%
type("")
# Out:
# str

# %%
type("a")
# Out:
# str

# %%
type('a')
# Out:
# str

# %%
type("Hola mundo mundial.")
# Out:
# str

# %%
type(True)
# Out:
# bool

# %%
type(False)
# Out:
# bool

# %%
type([])
# Out:
# list

# %%
type(())
# Out:
# tuple

# %%
type((1))
# Out:
# int

# %%
# Generar una tupla de un único elemento (coloco una coma a lado del único elemento)
type((1,))
# Out:
# tuple

# %%
# El conjunto se inicia con llaves y los elementos se separan con coma
type({1, 2, 3, 4, 5})
# Out:
# set

# %%
# Diccionarios. Son un juego llave-valor
type({"gato" : "mamífero de cuatro patas, perteneciente a los felinos"})
# Out:
# dict

# %%
diccionario = {"gato" : "mamífero de cuatro patas, perteneciente a los felinos"}

# %%
diccionario["gato"]
# Out:
# 'mamífero de cuatro patas, perteneciente a los felinos'
