# %% [markdown]
# 🟢 Examen Diagnóstico (Nivel Básico)
#
# Instrucciones: Escribe el código necesario para resolver cada uno de los siguientes 7 ejercicios.
#
# 1) Entrada y Salida de Datos: Escribe un programa que pregunte al usuario su nombre y su comida favorita. Luego, imprime una frase que diga: "A [Nombre] le encanta comer [Comida]".
#
# 2) Operaciones Matemáticas: Declara dos variables, base y altura, asígnales valores numéricos y calcula el área de un triángulo ($base \times altura / 2$). Imprime el resultado.
#
# 3) Condicionales Simples: Pide al usuario que ingrese un número entero. Escribe un bloque if/else que determine si el número es positivo, negativo o cero.
#
# 4) Listas Básicas: Crea una lista con 5 nombres de ciudades. Imprime el nombre de la ciudad que está en la posición 2 (Segundo elemento de lista). Usa .append() para agregar una ciudad más al final.Imprime la lista completa.
#
# 5) Ciclos (For): Escribe un ciclo for que imprima la tabla de multiplicar del 5 (del $5 \times 1$ al $5 \times 10$).
#
# 6) Strings (Slicing): Dada la palabra programacion = "Python", escribe el código para imprimir solamente las primeras 3 letras ("Pyt") usando slicing.
#
# 7) Funciones: Define una función llamada convertir_a_segundos que reciba una cantidad de minutos como parámetro y retorne la cantidad equivalente en segundos. Prueba la función con 10 minutos.
#
# Guerrero Rodríguez -> parcial

# %%
nombre = input("Por favor, ingrese su nombre: ")
comida = input("Por favor, ingrese su comida favorita: ")

print(f"A {nombre} le encanta comer {comida}")
# Out:
# A Miguel le encanta comer Pizza

# %%
base = 10.5
altura = 15
area = (base * altura) / 2
print(f"El área de un tríangulo con base {base} y altura {altura} es de: {area}")
# Out:
# El área de un tríangulo con base 10.5 y altura 15 es de: 78.75

# %%
numero = int(input("Por favor ingrese un número:"))

if numero == 0:
    print("Tu número es 0")
elif numero > 0:
    print("Tu número es positivo")
# elif numero < 0: 
else:
    print("Tu número es negativo")
# Out:
# Tu número es positivo

# %%
nombres = ["CDMX", "Cuernavaca", "París", "SLP", "Neza"]
print(nombres[1])
nombres.append("Chihuahua")
print(nombres)
# Out:
# Cuernavaca
# ['CDMX', 'Cuernavaca', 'París', 'SLP', 'Neza', 'Chihuahua']

# %%
for i in range(1, 11):
    print(f"5 x {i} = {5 * i}")
# Out:
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50

# %%
programacion = "Python"

programacion[:3]
# Out:
# 'Pyt'

# %%
def convertir_mins_segs(mins):
    return f"{mins} minutos a segundos son: {mins * 60} segundos"

segundos = convertir_mins_segs(60.5)
print(segundos)
# Out:
# 60.5 minutos a segundos son: 3630.0 segundos
