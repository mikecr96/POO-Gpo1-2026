# %%
# import time

# %%
# time.time()

# %%
from time import time

# %%
time()
# Out:
# 1771432371.8038862

# %%
from datetime import date, time, datetime, timedelta

# %%
fecha = date(1996, 12, 26)

# %%
type(fecha)
# Out:
# datetime.date

# %%
dir(fecha)
# Out:
# ['__add__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__radd__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__replace__',
#  '__repr__',
#  '__rsub__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  'ctime',
#  'day',
#  'fromisocalendar',
#  'fromisoformat',
#  'fromordinal',
#  'fromtimestamp',
#  'isocalendar',
#  'isoformat',
#  'isoweekday',
#  'max',
#  'min',
#  'month',
#  'replace',
#  'resolution',
#  'strftime',
#  'strptime',
#  'timetuple',
#  'today',
#  'toordinal',
#  'weekday',
#  'year']

# %%
fecha.today()
# Out:
# datetime.date(2026, 2, 18)

# %%
time()
# Out:
# datetime.time(0, 0)

# %%
delta = timedelta(
    days=50,
    seconds=27,
    microseconds=10,
    milliseconds=29000,
    minutes=5,
    hours=8,
    weeks=2
)
# Only days, seconds, and microseconds remain
delta
# Out:
# datetime.timedelta(days=64, seconds=29156, microseconds=10)

# %%
date.today()
# Out:
# datetime.date(2026, 2, 18)

# %%
ahora = datetime.now()
print(ahora.strftime("Día: %d | Mes: %m | Año: %Y, %H:%M:%S"))
# Out:
# Día: 18 | Mes: 02 | Año: 2026, 10:32:51

# %%
fecha = "18/02/2026 10:32:00"
datetime.strptime(fecha, "%d/%m/%Y %H:%M:%S")
# Out:
# datetime.datetime(2026, 2, 18, 10, 32)

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 fecha.month()
#
# AttributeError: 'str' object has no attribute 'month'
