# %% [markdown]
# # Operadores
#
# ## O. Aritméticos

# %%
"""
+ -> suma
- -> resta
* -> mult.
/ -> div.
"""

# %%
100 + 20
# Out:
# 120

# %%
1 + 1 + 1 + 1 + 1
# Out:
# 5

# %%
100 - 20
# Out:
# 80

# %%
100 - 200
# Out:
# -100

# %%
100 - 1 - 20 - 30
# Out:
# 49

# %%
5 * 5
# Out:
# 25

# %% [markdown]
# ## División

# %%
25 / 4
# Out:
# 6.25

# %%
int(25 / 4)
# Out:
# 6

# %%
# OMITE los décimales

25 // 14
# Out:
# 1

# %% [markdown]
# ## Agrupación

# %%
5 * (2 + 3)
# Out:
# 25

# %%
25 / (12.5 + 12.5)
# Out:
# 1.0

# %%
1 + 3 * 5 / 2
# Out:
# 8.5

# %%
(1 + 3) * 5 // 2
# Out:
# 10

# %% [markdown]
# ---

# %%
# Potencia
# base ** potencia

2 ** 10
# Out:
# 1024

# %%
5 ** 2
# Out:
# 25

# %%
# módulo (%)

10 % 2
# Out:
# 0

# %%
10 % 3
# Out:
# 1

# %% [markdown]
# ---
# ## O. lógicos

# %%
"""
> 
<
>=
<=
==
!=
(||) or
(&&) and
NOT
"""

# %%
10 > 3
# Out:
# True

# %%
1 < 2
# Out:
# True

# %%
10 > 10
# Out:
# False

# %%
10 >= 10
# Out:
# True

# %%
100 == 100
# Out:
# True

# %%
3.14151926 == 3.1416
# Out:
# False

# %%
int(3.14151926) == int(3.1416)
# Out:
# True

# %%
10 != 20
# Out:
# True

# %%
a = 10
b = 20

a != b
# Out:
# True

# %% [markdown]
# ## OR y AND

# %%
True or False # OR (con que UNO de los valores sea True, la salida es True)
# Out:
# True

# %%
False or True
# Out:
# True

# %%
True or True
# Out:
# True

# %%
False or False
# Out:
# False

# %% [markdown]
# ---
# ## AND

# %%
True and False # OR (los DOS valores tienen que ser True, para que la salida sea True)
# Out:
# False

# %%
False and False
# Out:
# False

# %%
False and True
# Out:
# False

# %%
# ESTA ES LA ÚNICA COMBINACIÓN EN DONDE AND DEVUELVE TRUE
True and True
# Out:
# True

# %%
(10 > 5) or (5 == 2)
# Out:
# True

# %%
(1 == 1) and (5 < 3)
# Out:
# False

# %%
(1 == 1) and (5 > 3)
# Out:
# True

# %% [markdown]
# ---
# ## NOT

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True

# %%
# !True

# %%
(1 == 1) and not (1 > 3)
# Out:
# True
